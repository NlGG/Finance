# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from openopt import QP
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 60

# %%
asset_class1 = {"e_return": 0.0250, "std": 0.0500}
asset_class2 = {"e_return": 0.0300, "std": 0.0550}
asset_class3 = {"e_return": 0.0600, "std": 0.0800}
asset_class4 = {"e_return": 0.0750, "std": 0.1000}
corr = [[1.00, 0.40, 0.30, 0.10], [0.40, 1.00, 0.50, 0.40], [0.30, 0.50, 1.00, 0.80], [0.10, 0.40, 0.80, 1.00]]
stds = [asset_class1["std"], asset_class2["std"], asset_class3["std"], asset_class4["std"]]
cov = [[0, 0, 0, 0] for i in range(4)]
for i in range(len(stds)):
    for j in range(len(stds)):
        cov[i][j] = stds[i]*stds[j]*corr[i][j]
cov = np.matrix(cov)
cov
# Out:
# matrix([[ 0.0025  ,  0.0011  ,  0.0012  ,  0.0005  ],
#         [ 0.0011  ,  0.003025,  0.0022  ,  0.0022  ],
#         [ 0.0012  ,  0.0022  ,  0.0064  ,  0.0064  ],
#         [ 0.0005  ,  0.0022  ,  0.0064  ,  0.01    ]])

# %%
effr = []
effs = []

for u in list(np.linspace(0.03, 0.07, 100)):
    H = cov
    f = [0, 0, 0, 0]
    Aeq = [[asset_class1["e_return"], asset_class2["e_return"], asset_class3["e_return"], asset_class4["e_return"]], [1,1,1,1]]
    beq = [u,1]
    lb = [0, 0, 0, 0]
    ub =  [1, 1, 1, 1]
    p = QP(H, f=f, Aeq=Aeq, beq=beq, lb=lb, ub=ub)
    r = p.solve("qlcp")
    w_opt = r.xf
    effr.append (w_opt[0]*asset_class1["e_return"] + w_opt[1]*asset_class2["e_return"] + w_opt[2]*asset_class3["e_return"] + w_opt[3]*asset_class4["e_return"])
    w_opt = np.matrix(w_opt)
    effs.append(math.sqrt(np.array(w_opt*cov*w_opt.T)[0][0]))
    print(w_opt, math.sqrt(np.array(w_opt*cov*w_opt.T)[0][0]))
# Out:
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.01 	CPU Time Elapsed = 0.01
# objFuncValue: 0.00092841755 (feasible, MaxResidual = 2.22045e-16)
# [[ 0.57925532  0.35638298  0.          0.0643617 ]] 0.04309100957720738
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.00092749604 (feasible, MaxResidual = 2.22045e-16)
# [[ 0.57620352  0.35079519  0.          0.07300129]] 0.04306961910593165
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.00092723743 (feasible, MaxResidual = 2.22045e-16)
# [[ 0.57315173  0.34520739  0.          0.08164088]] 0.04306361411797859
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.00092764171 (feasible, MaxResidual = 0)
# [[ 0.57009994  0.3396196   0.          0.09028046]] 0.04307300104821321
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.95
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.00092870888 (feasible, MaxResidual = 1.11022e-16)
# [[ 0.56704814  0.33403181  0.          0.09892005]] 0.04309776983930451
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.95
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.00093043895 (feasible, MaxResidual = 1.11022e-16)
# [[ 0.56399635  0.32844401  0.          0.10755964]] 0.04313789399552362
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.95
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.00093283191 (feasible, MaxResidual = 1.11022e-16)
# [[ 0.56094455  0.32285622  0.          0.11619923]] 0.043193330724099976
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.00093588776 (feasible, MaxResidual = 2.22045e-16)
# [[ 0.55789276  0.31726843  0.          0.12483881]] 0.043264021162381594
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.95
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.00093960651 (feasible, MaxResidual = 1.11022e-16)
# [[ 0.55484096  0.31168064  0.          0.1334784 ]] 0.04334989068800064
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.95
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.00094398815 (feasible, MaxResidual = 1.11022e-16)
# [[ 0.55178917  0.30609284  0.          0.14211799]] 0.04345084930826191
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.00094903269 (feasible, MaxResidual = 0)
# [[ 0.54873737  0.30050505  0.          0.15075758]] 0.043566792124071316
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.95
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.00095474012 (feasible, MaxResidual = 1.11022e-16)
# [[ 0.54568558  0.29491726  0.          0.15939716]] 0.04369759986292015
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.00096111044 (feasible, MaxResidual = 2.22045e-16)
# [[ 0.54263378  0.28932946  0.          0.16803675]] 0.0438431394747547
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.00096814366 (feasible, MaxResidual = 2.22045e-16)
# [[ 0.53958199  0.28374167  0.          0.17667634]] 0.04400326478399968
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.00097583977 (feasible, MaxResidual = 0)
# [[ 0.5365302   0.27815388  0.          0.18531593]] 0.04417781719057493
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.
FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   xmu = dot(BI, -concatenate([e + dot(A.T, lmbd), beq])) if Aeq != None else dot(BI, -(e + dot(A.T, lmbd)))

# %%
fig, ax = plt.subplots(figsize=(10, 8))
plt.title("oppotunity curve of portfolio")
plt.xlabel("Standard deviation")
plt.ylabel("Expected Return")

rtnp = []
stdp = []

for i in range(1000):
    a = np.random.uniform()
    
    if a < 0.4:
        w_1 = 0
        w_2 = 0
        w_3 = 0
        w_4 = np.random.uniform()
        w = w_1+ w_2 + w_3 + w_4
        w_1 = w_1/w
        w_2 = w_2/w
        w_3 = w_3/w
        w_4 = w_4/w
        wlist  = [w_1, w_2, w_3, w_4]
        np.random.shuffle(wlist)
        wmatrix = np.matrix(wlist).T
        
    elif 0.4 <= a < 0.6:
        w_1 = 0
        w_2 = 0
        w_3 = np.random.uniform()
        w_4 = np.random.uniform()
        w = w_1+ w_2 + w_3 + w_4
        w_1 = w_1/w
        w_2 = w_2/w
        w_3 = w_3/w
        w_4 = w_4/w
        wlist  = [w_1, w_2, w_3, w_4]
        np.random.shuffle(wlist)
        wmatrix = np.matrix(wlist).T
        
    elif a < 0.8:
        w_1 = 0
        w_2 = np.random.uniform()
        w_3 = np.random.uniform()
        w_4 = np.random.uniform()
        w = w_1+ w_2 + w_3 + w_4
        w_1 = w_1/w
        w_2 = w_2/w
        w_3 = w_3/w
        w_4 = w_4/w
        wlist  = [w_1, w_2, w_3, w_4]
        np.random.shuffle(wlist)
        wmatrix = np.matrix(wlist).T
        
    else:
        w_1 = np.random.uniform()
        w_2 = np.random.uniform()
        w_3 = np.random.uniform()
        w_4 = np.random.uniform()
        w = w_1+ w_2 + w_3 + w_4
        w_1 = w_1/w
        w_2 = w_2/w
        w_3 = w_3/w
        w_4 = w_4/w
        wlist  = [w_1, w_2, w_3, w_4]
        wmatrix = np.matrix(wlist).T
        
    rtnp.append(wlist[0]*asset_class1["e_return"] + wlist[1]*asset_class2["e_return"] + wlist[2]*asset_class3["e_return"] + wlist[3]*asset_class4["e_return"])
    stdp.append(math.sqrt(np.array(wmatrix.T*cov*wmatrix)[0][0]))

plt.plot(stdp, rtnp, "ko", markersize=5)
plt.plot(effs, effr, "k", linewidth=5)    
plt.plot(asset_class1["std"], asset_class1["e_return"], "ko", markersize=20)
plt.plot(asset_class2["std"], asset_class2["e_return"], "ko", markersize=20)
plt.plot(asset_class3["std"], asset_class3["e_return"], "ko", markersize=20)
plt.plot(asset_class4["std"], asset_class4["e_return"], "ko", markersize=20)
plt.show()

# %%
import jsm
q = jsm.Quotes()

import datetime

start_date = datetime.date(1996,12, 1)
end_date = datetime.date(2014,12, 1)

nomura = q.get_historical_prices(8604, jsm.MONTHLY, start_date = start_date, end_date = end_date)

nsn= q.get_historical_prices(7201, jsm.MONTHLY, start_date = start_date, end_date = end_date)

toshiba = q.get_historical_prices(6502, jsm.MONTHLY, start_date = start_date, end_date = end_date)
# Out:
# /Users/NIGG/anaconda/lib/python3.5/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
nomura_high_list = [each_month_data.high for each_month_data in nomura]
nomura_low_list = [each_month_data.low for each_month_data in nomura]
nomura_return = []
for i in range(1, len(nomura_high_list)):
    nomura_return.append(((nomura_high_list[i]+nomura_low_list[i])/2)/((nomura_high_list[i-1]+nomura_low_list[i-1])/2)-1)
nomura_return = np.array(nomura_return)

# %%
nsn_high_list = [each_month_data.high for each_month_data in nsn]
nsn_low_list = [each_month_data.low for each_month_data in nsn]
nsn_return = []
for i in range(1, len(nsn_high_list)):
    nsn_return.append(((nsn_high_list[i]+nsn_low_list[i])/2)/((nsn_high_list[i-1]+nsn_low_list[i-1])/2)-1)
nsn_return = np.array(nsn_return)

# %%
toshiba_high_list = [each_month_data.high for each_month_data in toshiba]
toshiba_low_list = [each_month_data.low for each_month_data in toshiba]
toshiba_return = []
for i in range(1, len(toshiba_high_list)):
    toshiba_return.append(((toshiba_high_list[i]+toshiba_low_list[i])/2)/((toshiba_high_list[i-1]+toshiba_low_list[i-1])/2)-1)
toshiba_return = np.array(toshiba_return)

# %%
nmr_av = np.average(nomura_return)
nmr_std = np.std(nomura_return)
nsn_av = np.average(nsn_return)
nsn_std = np.std(nsn_return)
tsb_av = np.average(toshiba_return)
tsb_std = np.std(toshiba_return)
plt.plot([nmr_std, nsn_std, tsb_std],[nmr_av, nsn_av, tsb_av], "o")

# %%
nmr_nsc_tsb = np.corrcoef([nomura_return, nsn_return, toshiba_return])
nmr_nsc_tsb
# Out:
# array([[ 1.        ,  0.53502897,  0.58720978],
#        [ 0.53502897,  1.        ,  0.48133133],
#        [ 0.58720978,  0.48133133,  1.        ]])

# %%
stds = [nmr_std, nsn_std, tsb_std]
cov = [[0, 0, 0] for i in range(3)]
for i in range(len(stds)):
    for j in range(len(stds)):
        cov[i][j] = stds[i]*stds[j]*nmr_nsc_tsb[i][j]
cov = np.matrix(cov)
cov
# Out:
# matrix([[ 0.01101034,  0.00495225,  0.00563923],
#         [ 0.00495225,  0.00778127,  0.00388593],
#         [ 0.00563923,  0.00388593,  0.0083763 ]])

# %%
effr = []
effs = []

for u in list(np.linspace(0.004, 0.009, 100)):
    H = cov
    f = [0, 0, 0]
    Aeq = [[nmr_av, nsn_av, tsb_av], [1,1,1]]
    beq = [u,1]
    lb = [0, 0, 0]
    ub =  [1, 1, 1]
    p = QP(H, f=f, Aeq=Aeq, beq=beq, lb=lb, ub=ub)
    r = p.solve("qlcp")
    w_opt = r.xf
    effr.append (w_opt[0]*nmr_av + w_opt[1]*nsn_av + w_opt[2]*tsb_av)
    w_opt = np.matrix(w_opt)
    effs.append(math.sqrt(np.array(w_opt*cov*w_opt.T)[0][0]))
    print(w_opt, math.sqrt(np.array(w_opt*cov*w_opt.T)[0][0]))
# Out:
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0029524744 (feasible, MaxResidual = 0)
# [[ 0.07485309  0.51787222  0.4072747 ]] 0.07684366419094439
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.95
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0029507364 (feasible, MaxResidual = 1.11022e-16)
# [[ 0.08155544  0.51169171  0.40675285]] 0.0768210445989206
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.002949368 (feasible, MaxResidual = 0)
# [[ 0.08825779  0.50551121  0.406231  ]] 0.07680322885634033
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.002948369 (feasible, MaxResidual = 0)
# [[ 0.09496014  0.49933071  0.40570916]] 0.07679022030676004
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0029477394 (feasible, MaxResidual = 0)
# [[ 0.10166249  0.49315021  0.40518731]] 0.0767820213935099
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0029474793 (feasible, MaxResidual = 0)
# [[ 0.10836483  0.48696971  0.40466546]] 0.07677863365740105
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0029475886 (feasible, MaxResidual = 0)
# [[ 0.11506718  0.4807892   0.40414361]] 0.0767800577352785
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0029480674 (feasible, MaxResidual = 0)
# [[ 0.12176953  0.4746087   0.40362176]] 0.07678629335942266
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.95
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0029489157 (feasible, MaxResidual = 1.11022e-16)
# [[ 0.12847188  0.4684282   0.40309992]] 0.07679733935780099
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.95
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0029501334 (feasible, MaxResidual = 1.11022e-16)
# [[ 0.13517423  0.4622477   0.40257807]] 0.07681319365516903
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0041242727 (feasible, MaxResidual = 0)
# [[ 0.65093294  0.          0.34906706]] 0.09082150338789088
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0041552956 (feasible, MaxResidual = 2.22045e-16)
# [[ 0.66291372  0.          0.33708628]] 0.09116244360619497
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0041874822 (feasible, MaxResidual = 0)
# [[ 0.6748945  0.         0.3251055]] 0.09151483186557562
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0042208327 (feasible, MaxResidual = 0)
# [[ 0.68687527  0.          0.31312473]] 0.0918785364436785
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0042553471 (feasible, MaxResidual = 2.22045e-16)
# [[ 0.69885605  0.          0.30114395]] 0.09225342349851325
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0042910253 (feasible, MaxResidual = 0)
# [[ 0.71083683  0.          0.28916317]] 0.09263935727257404
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0043278673 (feasible, MaxResidual = 2.22045e-16)
# [[ 0.72281761  0.          0.27718239]] 0.09303620029360123
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.95
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0043658731 (feasible, MaxResidual = 1.11022e-16)
# [[ 0.73479839  0.          0.26520161]] 0.09344381357148503
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0044050429 (feasible, MaxResidual = 0)
# [[ 0.74677917  0.          0.25322083]] 0.09386205679085513
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0044453764 (feasible, MaxResidual = 0)
# [[ 0.75875995  0.          0.24124005]] 0.09429078849894547
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0044868738 (feasible, MaxResidual = 0)
# [[ 0.77074073  0.          0.22925927]] 0.09472986628836715
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.004529535 (feasible, MaxResidual = 2.22045e-16)
# [[ 0.7827215  0.         0.2172785]] 0.09517914697446525
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0045733601 (feasible, MaxResidual = 2.22045e-16)
# [[ 0.79470228  0.          0.20529772]] 0.09563848676697942
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.95
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.004618349 (feasible, MaxResidual = 1.11022e-16)
# [[ 0.80668306  0.          0.19331694]] 0.09610774143576796
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0046645017 (feasible, MaxResidual = 0)
# [[ 0.81866384  0.          0.18133616]] 0.09658676647039725
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:39: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if lb != None:
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:43: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   A = vstack([A, -addA]) if A != None else -addA
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:44: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   b = concatenate([b, -addb]) if b != None else -addb
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:45: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if ub != None:
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:49: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   A = vstack([A, addA]) if A != None else addA
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:50: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   b = concatenate([b, addb]) if b != None else addb
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:132: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if Aeq != None:
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:150: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   q = b + dot(A0BI, concatenate((e, beq))) if Aeq != None else b + dot(A0BI, e)
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   xmu = dot(BI, -concatenate([e + dot(A.T, lmbd), beq])) if Aeq != None else dot(BI, -(e + dot(A.T, lmbd)))

# %%
plt.plot(effs, effr, '#88ffff', linewidth=3)    
plt.plot([nmr_std, nsn_std, tsb_std],[nmr_av, nsn_av, tsb_av], "o")

# %%
for i in range(97):
    nmr_av = np.average(nomura_return[-120-i-1:-i-1])
    nmr_std = np.std(nomura_return[-120-i-1:-i-1])
    nsn_av = np.average(nsn_return[-120-i-1:-i-1])
    nsn_std = np.std(nsn_return[-120-i-1:-i-1])
    tsb_av = np.average(toshiba_return[-120-i-1:-i-1])
    tsb_std = np.std(toshiba_return[-120-i-1:-i-1])
    
    nmr_nsc_tsb = np.corrcoef([nomura_return, nsn_return, toshiba_return])
    nmr_nsc_tsb
    
    stds = [nmr_std, nsn_std, tsb_std]
    cov = [[0, 0, 0] for i in range(3)]
    for i in range(len(stds)):
        for j in range(len(stds)):
            cov[i][j] = stds[i]*stds[j]*nmr_nsc_tsb[i][j]
    cov = np.matrix(cov)
    
    effr = []
    effs = []

    for u in list(np.linspace(0.002, 0.025, 15)):
        H = cov
        f = [0, 0, 0]
        Aeq = [[nmr_av, nsn_av, tsb_av], [1,1,1]]
        beq = [u,1]
        lb = [0, 0, 0]
        ub =  [1, 1, 1]
        p = QP(H, f=f, Aeq=Aeq, beq=beq, lb=lb, ub=ub)
        r = p.solve("qlcp")
        w_opt = r.xf
        if w_opt[0]*nmr_av + w_opt[1]*nsn_av + w_opt[2]*tsb_av > 0.002:
            effr.append (w_opt[0]*nmr_av + w_opt[1]*nsn_av + w_opt[2]*tsb_av)
            w_opt = np.matrix(w_opt)
            effs.append(math.sqrt(np.array(w_opt*cov*w_opt.T)[0][0]))
        plt.plot(effs, effr, "k", linewidth=1)
# Out:
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.36
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0028158033 (feasible, MaxResidual = 4.33681e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.36
# istop: 1000
# Solver:   Time Elapsed = 0.01 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0026428217 (feasible, MaxResidual = 4.33681e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.01 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0028641795 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0034935556 (feasible, MaxResidual = 8.67362e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.36
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0035212006 (feasible, MaxResidual = 4.33681e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# ...
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.003206085 (feasible, MaxResidual = 8.67362e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0031813897 (feasible, MaxResidual = 8.67362e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0034423228 (feasible, MaxResidual = 8.67362e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0039888843 (feasible, MaxResidual = 2.22045e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0048518284 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0032396366 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0032008619 (feasible, MaxResidual = 8.67362e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.76
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0034509409 (feasible, MaxResidual = 1.73472e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.95
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0039889006 (feasible, MaxResidual = 1.11022e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0048690032 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:39: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if lb != None:
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:43: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   A = vstack([A, -addA]) if A != None else -addA
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:44: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   b = concatenate([b, -addb]) if b != None else -addb
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:45: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if ub != None:
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:49: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   A = vstack([A, addA]) if A != None else addA
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:50: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   b = concatenate([b, addb]) if b != None else addb
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:132: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if Aeq != None:
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:150: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   q = b + dot(A0BI, concatenate((e, beq))) if Aeq != None else b + dot(A0BI, e)
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   xmu = dot(BI, -concatenate([e + dot(A.T, lmbd), beq])) if Aeq != None else dot(BI, -(e + dot(A.T, lmbd)))

# %%
for i in range(73):
    nmr_av = np.average(nomura_return[-144-i-1:-i-1])
    nmr_std = np.std(nomura_return[-144-i-1:-i-1])
    nsn_av = np.average(nsn_return[-144-i-1:-i-1])
    nsn_std = np.std(nsn_return[-144-i-1:-i-1])
    tsb_av = np.average(toshiba_return[-144-i-1:-i-1])
    tsb_std = np.std(toshiba_return[-144-i-1:-i-1])
    
    nmr_nsc_tsb = np.corrcoef([nomura_return, nsn_return, toshiba_return])
    nmr_nsc_tsb
    
    stds = [nmr_std, nsn_std, tsb_std]
    cov = [[0, 0, 0] for i in range(3)]
    for i in range(len(stds)):
        for j in range(len(stds)):
            cov[i][j] = stds[i]*stds[j]*nmr_nsc_tsb[i][j]
    cov = np.matrix(cov)
    
    effr = []
    effs = []

    for u in list(np.linspace(0.002, 0.025, 15)):
        H = cov
        f = [0, 0, 0]
        Aeq = [[nmr_av, nsn_av, tsb_av], [1,1,1]]
        beq = [u,1]
        lb = [0, 0, 0]
        ub =  [1, 1, 1]
        p = QP(H, f=f, Aeq=Aeq, beq=beq, lb=lb, ub=ub)
        r = p.solve("qlcp")
        w_opt = r.xf
        if w_opt[0]*nmr_av + w_opt[1]*nsn_av + w_opt[2]*tsb_av > 0.002:
            effr.append (w_opt[0]*nmr_av + w_opt[1]*nsn_av + w_opt[2]*tsb_av)
            w_opt = np.matrix(w_opt)
            effs.append(math.sqrt(np.array(w_opt*cov*w_opt.T)[0][0]))
        plt.plot(effs, effr, "k", linewidth=1)
# Out:
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:39: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if lb != None:
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:43: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   A = vstack([A, -addA]) if A != None else -addA
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:44: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   b = concatenate([b, -addb]) if b != None else -addb
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:45: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if ub != None:
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:49: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   A = vstack([A, addA]) if A != None else addA
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:50: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   b = concatenate([b, addb]) if b != None else addb
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:132: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if Aeq != None:
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:150: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   q = b + dot(A0BI, concatenate((e, beq))) if Aeq != None else b + dot(A0BI, e)
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   xmu = dot(BI, -concatenate([e + dot(A.T, lmbd), beq])) if Aeq != None else dot(BI, -(e + dot(A.T, lmbd)))
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0030183534 (feasible, MaxResidual = 8.67362e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.16
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0037832917 (feasible, MaxResidual = 6.93889e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.01 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.18
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0032877672 (feasible, MaxResidual = 6.66134e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0032806631 (feasible, MaxResidual = 2.22045e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.35
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0036820861 (feasible, MaxResidual = 4.44089e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0036219477 (feasible, MaxResidual = 2.22045e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.48
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0038308861 (feasible, MaxResidual = 3.33067e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0045607033 (feasible, MaxResidual = 2.22045e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.003371228 (feasible, MaxResidual = 2.22045e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.28
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0040764204 (feasible, MaxResidual = 5.20417e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0044987849 (feasible, MaxResidual = 2.22045e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0034277932 (feasible, MaxResidual = 2.22045e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -16.98
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0042146685 (feasible, MaxResidual = 1.04083e-17)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0034074459 (feasible, MaxResidual = 2.22045e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.48
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0047928997 (feasible, MaxResidual = 3.33067e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.36
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0044134335 (feasible, MaxResidual = 4.33681e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.46
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0034434104 (feasible, MaxResidual = 3.46945e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.46
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.00373986 (feasible, MaxResidual = 3.46945e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.76
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0051762769 (feasible, MaxResidual = 1.73472e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0034466952 (feasible, MaxResidual = 2.22045e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0037302313 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0046980971 (feasible, MaxResidual = 2.22045e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# ...
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.95
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0039746174 (feasible, MaxResidual = 1.11022e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.36
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0029087497 (feasible, MaxResidual = 4.33681e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.95
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.003140365 (feasible, MaxResidual = 1.11022e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0036811817 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0045891706 (feasible, MaxResidual = 2.22045e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.95
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0029003675 (feasible, MaxResidual = 1.11022e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.95
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.003096996 (feasible, MaxResidual = 1.11022e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0035872081 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0043941219 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.36
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0029173269 (feasible, MaxResidual = 4.33681e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0031022108 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0035808014 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0043603222 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)

# %%
w_005 = []
w_01 = []


for i in range(97):
    nmr_av = np.average(nomura_return[-120-i-1:-i-1])
    nmr_std = np.std(nomura_return[-120-i-1:-i-1])
    nsn_av = np.average(nsn_return[-120-i-1:-i-1])
    nsn_std = np.std(nsn_return[-120-i-1:-i-1])
    tsb_av = np.average(toshiba_return[-120-i-1:-i-1])
    tsb_std = np.std(toshiba_return[-120-i-1:-i-1])
    
    nmr_nsc_tsb = np.corrcoef([nomura_return, nsn_return, toshiba_return])
    nmr_nsc_tsb
    
    stds = [nmr_std, nsn_std, tsb_std]
    cov = [[0, 0, 0] for i in range(3)]
    for i in range(len(stds)):
        for j in range(len(stds)):
            cov[i][j] = stds[i]*stds[j]*nmr_nsc_tsb[i][j]
    cov = np.matrix(cov)
    
    effr = []
    effs = []
    
    for u in [0.005,0.01]:
        H = cov
        f = [0, 0, 0]
        Aeq = [[nmr_av, nsn_av, tsb_av], [1,1,1]]
        beq = [u,1]
        lb = [0, 0, 0]
        ub =  [1, 1, 1]
        p = QP(H, f=f, Aeq=Aeq, beq=beq, lb=lb, ub=ub)
        r = p.solve("qlcp")
        w_opt = r.xf
        if w_opt[0]*nmr_av + w_opt[1]*nsn_av + w_opt[2]*tsb_av > 0.002:
            effr.append (w_opt[0]*nmr_av + w_opt[1]*nsn_av + w_opt[2]*tsb_av)
            w_opt = np.matrix(w_opt)
            effs.append(math.sqrt(np.array(w_opt*cov*w_opt.T)[0][0]))
            if u == 0.005:
                w_005.append(w_opt)
            else:
                w_01.append(w_opt)
# Out:
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:39: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if lb != None:
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:43: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   A = vstack([A, -addA]) if A != None else -addA
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:44: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   b = concatenate([b, -addb]) if b != None else -addb
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:45: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if ub != None:
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:49: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   A = vstack([A, addA]) if A != None else addA
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:50: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   b = concatenate([b, addb]) if b != None else addb
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:132: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if Aeq != None:
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:150: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   q = b + dot(A0BI, concatenate((e, beq))) if Aeq != None else b + dot(A0BI, e)
# /Users/NIGG/anaconda/lib/python3.5/site-packages/openopt/solvers/HongKongOpt/QPSolve.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   xmu = dot(BI, -concatenate([e + dot(A.T, lmbd), beq])) if Aeq != None else dot(BI, -(e + dot(A.T, lmbd)))
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0044798332 (feasible, MaxResidual = 8.67362e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0044014071 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.01 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.07 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.95
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0044985473 (feasible, MaxResidual = 1.11022e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0032326428 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0031159214 (feasible, MaxResidual = 8.67362e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.95
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0033165311 (feasible, MaxResidual = 1.11022e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0033250704 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.58
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0046011128 (feasible, MaxResidual = 2.60209e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.76
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0034548454 (feasible, MaxResidual = 1.73472e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0043468775 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0037796567 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0042793123 (feasible, MaxResidual = 8.67362e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.76
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0039100402 (feasible, MaxResidual = 1.73472e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0047372218 (feasible, MaxResidual = 8.67362e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.76
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0035182124 (feasible, MaxResidual = 1.73472e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0043496928 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0037974014 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.76
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0037369415 (feasible, MaxResidual = 1.73472e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0037161282 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0037518881 (feasible, MaxResidual = 8.67362e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.76
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0037044942 (feasible, MaxResidual = 1.73472e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0034955314 (feasible, MaxResidual = 8.67362e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.76
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0038355371 (feasible, MaxResidual = 1.73472e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0034728391 (feasible, MaxResidual = 8.67362e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.76
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0037844005 (feasible, MaxResidual = 1.73472e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0035230892 (feasible, MaxResidual = 2.22045e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.76
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0034530473 (feasible, MaxResidual = 1.73472e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0035082926 (feasible, MaxResidual = 8.67362e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0034310174 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0034976435 (feasible, MaxResidual = 8.67362e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0034644379 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.58
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0036974961 (feasible, MaxResidual = 2.60209e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.46
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0033862964 (feasible, MaxResidual = 3.46945e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.95
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0039258962 (feasible, MaxResidual = 1.11022e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.95
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0033779271 (feasible, MaxResidual = 1.11022e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0039835626 (feasible, MaxResidual = 8.67362e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0033778614 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0037411816 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0033644244 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.58
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0037652529 (feasible, MaxResidual = 2.60209e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.76
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0033586759 (feasible, MaxResidual = 1.73472e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.01 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0037646995 (feasible, MaxResidual = 2.22045e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.95
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0033163977 (feasible, MaxResidual = 1.11022e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0037617556 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.76
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0033158216 (feasible, MaxResidual = 1.73472e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0035639403 (feasible, MaxResidual = 8.67362e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.76
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0033642731 (feasible, MaxResidual = 1.73472e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0035184608 (feasible, MaxResidual = 8.67362e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.95
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0034134871 (feasible, MaxResidual = 1.11022e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0034697416 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0034114723 (feasible, MaxResidual = 2.22045e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0043016699 (feasible, MaxResidual = 2.22045e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0033831005 (feasible, MaxResidual = 2.22045e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.28
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0033588168 (feasible, MaxResidual = 5.20417e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.76
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0041427565 (feasible, MaxResidual = 1.73472e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.95
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0033644796 (feasible, MaxResidual = 1.11022e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.95
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0039440787 (feasible, MaxResidual = 1.11022e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.95
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0033449344 (feasible, MaxResidual = 1.11022e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0038603482 (feasible, MaxResidual = 8.67362e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.95
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0033382557 (feasible, MaxResidual = 1.11022e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.95
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0042951044 (feasible, MaxResidual = 1.11022e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.76
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0033846591 (feasible, MaxResidual = 1.73472e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.00331015 (feasible, MaxResidual = 8.67362e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0031900986 (feasible, MaxResidual = 2.22045e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.76
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0032635202 (feasible, MaxResidual = 1.73472e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.76
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0032129758 (feasible, MaxResidual = 1.73472e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0032901083 (feasible, MaxResidual = 8.67362e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0031945223 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0033020096 (feasible, MaxResidual = 8.67362e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.76
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0031707544 (feasible, MaxResidual = 1.73472e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0033199715 (feasible, MaxResidual = 8.67362e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.76
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0031477917 (feasible, MaxResidual = 1.73472e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.95
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0032830784 (feasible, MaxResidual = 1.11022e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0032888433 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.58
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.003345726 (feasible, MaxResidual = 2.60209e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.76
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0031733794 (feasible, MaxResidual = 1.73472e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.003481775 (feasible, MaxResidual = 2.22045e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.76
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0031341763 (feasible, MaxResidual = 1.73472e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.95
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# ...
#     1  0.000e+00             -18.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0032180093 (feasible, MaxResidual = 8.67362e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.46
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0043382877 (feasible, MaxResidual = 3.46945e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0033124359 (feasible, MaxResidual = 8.67362e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.76
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0054109343 (feasible, MaxResidual = 1.73472e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.76
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0036289484 (feasible, MaxResidual = 1.73472e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0032344796 (feasible, MaxResidual = 2.22045e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.48
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0049149667 (feasible, MaxResidual = 3.33067e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0031935939 (feasible, MaxResidual = 8.67362e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0044101478 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0041762766 (feasible, MaxResidual = 2.22045e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.95
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.003792381 (feasible, MaxResidual = 1.11022e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0037049901 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.58
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0036722487 (feasible, MaxResidual = 2.60209e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0038730857 (feasible, MaxResidual = 2.22045e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.76
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0033188821 (feasible, MaxResidual = 1.73472e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.46
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0039837592 (feasible, MaxResidual = 3.46945e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0032180743 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0039373259 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.004141638 (feasible, MaxResidual = 8.67362e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.95
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0038636297 (feasible, MaxResidual = 1.11022e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.76
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0035832057 (feasible, MaxResidual = 1.73472e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.76
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0034706615 (feasible, MaxResidual = 1.73472e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00               0.00
# istop: -1
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# NO FEASIBLE SOLUTION has been obtained (MaxResidual = 1, objFunc = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0036319298 (feasible, MaxResidual = 2.22045e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0031841825 (feasible, MaxResidual = 8.67362e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.76
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0040815939 (feasible, MaxResidual = 1.73472e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0031485234 (feasible, MaxResidual = 8.67362e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0041494739 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0031425486 (feasible, MaxResidual = 8.67362e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -17.76
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0041067908 (feasible, MaxResidual = 1.73472e-18)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0031417156 (feasible, MaxResidual = 8.67362e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0042599559 (feasible, MaxResidual = 2.22045e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0031669905 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0041522786 (feasible, MaxResidual = 0)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0031656679 (feasible, MaxResidual = 8.67362e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0050152025 (feasible, MaxResidual = 2.22045e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0031651668 (feasible, MaxResidual = 8.67362e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -15.65
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0047163884 (feasible, MaxResidual = 2.22045e-16)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00             -18.06
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0031867566 (feasible, MaxResidual = 8.67362e-19)
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: qlcp
#   iter  objFunVal  log10(maxResidual)
#     0  0.000e+00               0.00
#     1  0.000e+00            -100.00
# istop: 1000
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: 0.0047288967 (feasible, MaxResidual = 0)

# %%
w_005 = np.array(w_005)
w_01 = np.array(w_01)

# %%
for i in range(len(w_005)):
    w_005[i][0][0] = w_005[i][0][0]
    w_005[i][0][1] = w_005[i][0][0] + w_005[i][0][1]
    w_005[i][0][2] = w_005[i][0][1] + w_005[i][0][2]
    
for i in range(len(w_01)):
    w_01[i][0][0] = w_01[i][0][0]
    w_01[i][0][1] = w_01[i][0][0] + w_01[i][0][1]
    w_01[i][0][2] = w_01[i][0][1] + w_01[i][0][2]

# %%
w_005[0][0]
# Out:
# array([ 0.9968669,  1.9937338,  2.9937338])

# %%
plt.plot([w[0] for w in w_005])
# Out:
# [<matplotlib.lines.Line2D at 0x10fc0a5c0>,
#  <matplotlib.lines.Line2D at 0x10fc0aa90>,
#  <matplotlib.lines.Line2D at 0x10fc0ac88>]

# %%
plt.plot([w[0] for w in w_01])
# Out:
# [<matplotlib.lines.Line2D at 0x11fd0b940>,
#  <matplotlib.lines.Line2D at 0x11fd0bd30>,
#  <matplotlib.lines.Line2D at 0x11fd0b7b8>]
